# %%
artsy <- read.csv("C:/Users/Sahab/Downloads/artsy.csv")

# %%
library('MASS')

# %%
library(psych)
cor(artsy,method='spearman')
pairs.panels(artsy)
# Out:
#           RATE      TinG       SEX       GRD
# RATE 1.0000000 0.4032505 0.5719399 0.9048103
# TinG 0.4032505 1.0000000 0.3279514 0.2883447
# SEX  0.5719399 0.3279514 1.0000000 0.5512456
# GRD  0.9048103 0.2883447 0.5512456 1.0000000
# plot without title

# %% [markdown]
# 1) Overall, how different is pay by sex? Are the differences in pay statistically significant? Is a statistical hypothesis test appropriate in an issue like this? If so, how should it be done? How could it be explained to a judge? What arguments do you anticipate the plaintiffs will be making with these data?

# %%
ols <- lm(RATE~SEX, artsy)
#plot(ols)
summary(ols)
# Out:
# Call:
# lm(formula = RATE ~ SEX, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -398.18 -123.12  -10.97  112.17  557.23
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   832.77      13.96   59.66   <2e-16 ***
# SEX           295.40      24.22   12.20   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 182.5 on 254 degrees of freedom
# Multiple R-squared:  0.3693,	Adjusted R-squared:  0.3668
# F-statistic: 148.7 on 1 and 254 DF,  p-value: < 2.2e-16

# %% [markdown]
# A male earn $295.40 more on average in wages than females. The differences in pay is highly statistically significant and we can reject the null hypothesis and indeed there is a relationship between sex and the wages. However, this regresion model alone does not prove causation or descrimination. (Add possible arguments)

# %% [markdown]
# 2) The Artsy Company wishes to argue that a legitimate explanation of any pay rate difference is the difference in job grades by sex. (In this analysis we will tacitly assume that each person's job grade is, in fact, appropriate for them, even though the plaintiff's attorneys have charged that females have been unfairly kept in the lower grades. Other statistical data, not available here, are used in the analysis of the job placement issue.) The company’s lawyers ask, "Is there a relatively easy way to understand, to analyze and display the pay differences by job grade? Easy enough that it could be presented to an average jury without confusing them?” Again, try to anticipate the possible arguments of the plaintiffs. To what extent does job grade appear to explain the pay rate differences between the sexes? Propose and carry out appropriate hypothesis tests or confidence intervals to check whether the difference in pay between sexes is statistically significant within each of the grades.
#
# Pay grade is positively correlated with the gender and highly correlated with the pay rate.

# %%
ols <- lm(RATE~SEX+GRD, artsy)
#plot(ols)
summary(ols)
# Out:
# Call:
# lm(formula = RATE ~ SEX + GRD, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -297.19  -63.42   -4.13   59.49  322.35
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  549.753     14.878  36.952  < 2e-16 ***
# SEX           88.786     16.686   5.321 2.27e-07 ***
# GRD           79.730      3.525  22.616  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 105.2 on 253 degrees of freedom
# Multiple R-squared:  0.7913,	Adjusted R-squared:  0.7896
# F-statistic: 479.5 on 2 and 253 DF,  p-value: < 2.2e-16

# %%
#####IGNORE THIS##########

artsy$grade <- factor(artsy$GRD)
ols <- lm(RATE~SEX+grade+ SEX*grade, artsy)
#plot(ols)
summary(ols)
# Out:
# Call:
# lm(formula = RATE ~ SEX + grade + SEX * grade, data = artsy)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -260.848  -58.784   -7.674   49.788  306.152
#
# Coefficients: (1 not defined because of singularities)
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   664.68      20.13  33.022  < 2e-16 ***
# SEX           139.32      96.53   1.443   0.1503
# grade2         60.79      24.08   2.524   0.0122 *
# grade3        165.41      28.47   5.811 1.96e-08 ***
# grade4        168.98      30.01   5.632 4.95e-08 ***
# grade5        222.32      27.87   7.978 6.02e-14 ***
# grade6        341.52      31.61  10.803  < 2e-16 ***
# grade7        428.55      30.49  14.057  < 2e-16 ***
# grade8        609.32      69.73   8.739 4.07e-16 ***
# SEX:grade2        NA         NA      NA       NA
# SEX:grade3   -134.08     103.51  -1.295   0.1965
# SEX:grade4   -148.78     107.69  -1.382   0.1684
# SEX:grade5   -107.68     102.47  -1.051   0.2944
# SEX:grade6    -14.72     103.94  -0.142   0.8875
# SEX:grade7    -19.70     100.56  -0.196   0.8448
# SEX:grade8    -37.38     119.72  -0.312   0.7551
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 94.41 on 241 degrees of freedom
# Multiple R-squared:  0.8399,	Adjusted R-squared:  0.8306
# F-statistic:  90.3 on 14 and 241 DF,  p-value: < 2.2e-16

# %% [markdown]
# 3) In the actual case, the analysis carried out in (2) above suggested to the attorneys that differences in pay rates are due, at least in part, to differences in job grades. They had heard that in another EEO case the dependence of pay rate on job grade had been investigated with regression analysis. Perform a simple linear regression of pay rate on job grade. Interpret the results fully. Is the regression significant? How much of the variability in pay does job grade account for? What light does this analysis shed on the pay fairness issue? Does it help or hurt the Artsy company?

# %%
ols <-lm(RATE~grade, artsy)
ols2<-lm(RATE~GRD, artsy)

summary(ols)
summary(ols2)
# Out:
# Call:
# lm(formula = RATE ~ grade, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -220.18  -66.43   -6.61   54.66  346.82
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   670.74      20.71  32.384  < 2e-16 ***
# grade2         54.73      24.95   2.194   0.0292 *
# grade3        160.87      27.34   5.885 1.28e-08 ***
# grade4        160.87      29.29   5.492 9.83e-08 ***
# grade5        226.20      26.66   8.484 1.99e-15 ***
# grade6        385.30      28.70  13.425  < 2e-16 ***
# grade7        501.44      25.03  20.036  < 2e-16 ***
# grade8        693.87      31.26  22.197  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 99.33 on 248 degrees of freedom
# Multiple R-squared:  0.8176,	Adjusted R-squared:  0.8125
# F-statistic: 158.8 on 7 and 248 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = RATE ~ GRD, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -243.94  -80.94   -0.44   66.56  355.06
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  533.937     15.341   34.80   <2e-16 ***
# GRD           90.001      3.105   28.99   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 110.7 on 254 degrees of freedom
# Multiple R-squared:  0.7679,	Adjusted R-squared:  0.767
# F-statistic: 840.4 on 1 and 254 DF,  p-value: < 2.2e-16

# %% [markdown]
# 4) It is argued that seniority within a job grade should be taken into account since the Artsy Company's written pay policy explicitly calls for the consideration of this factor. How different are times in grade by sex? Enough to matter?

# %%
ols<-lm(TinG~SEX, artsy)
summary(ols)
# Out:
# Call:
# lm(formula = TinG ~ SEX, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.2282 -0.7860 -0.2860  0.8718  3.7140
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.2860     0.1044  12.322  < 2e-16 ***
# SEX           1.3423     0.1811   7.411 1.86e-12 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.365 on 254 degrees of freedom
# Multiple R-squared:  0.1778,	Adjusted R-squared:  0.1746
# F-statistic: 54.93 on 1 and 254 DF,  p-value: 1.858e-12

# %% [markdown]
# Men spend, on average, over 1.3 years more than women.

# %%
ols<-lm(TinG~SEX+grade, artsy)
summary(ols)

### time spend on average per grade is .8 years more than women (you can add the duration for each grade to get mean for
##specific grade) The higher the grade, more years men have in that paygrade
# Out:
# Call:
# lm(formula = TinG ~ SEX + grade, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.6003 -0.7345 -0.1100  0.4748  3.9382
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.33244    0.27220   4.895 1.78e-06 ***
# SEX          0.85389    0.21221   4.024 7.62e-05 ***
# grade2      -0.11871    0.32782  -0.362   0.7176
# grade3      -0.27067    0.36285  -0.746   0.4564
# grade4      -0.72242    0.38649  -1.869   0.0628 .
# grade5      -0.09795    0.35489  -0.276   0.7828
# grade6       0.15000    0.38447   0.390   0.6968
# grade7       0.91399    0.35379   2.583   0.0104 *
# grade8       0.81410    0.44806   1.817   0.0704 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.305 on 247 degrees of freedom
# Multiple R-squared:  0.2693,	Adjusted R-squared:  0.2456
# F-statistic: 11.38 on 8 and 247 DF,  p-value: 1.028e-13

# %%
ols<-lm(RATE~TinG, artsy)
summary(ols)

#For every single extra year- you make an extra $82 on average
# Out:
# Call:
# lm(formula = RATE ~ TinG, data = artsy)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -528.45 -124.83  -25.65   97.40  589.40
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  788.490     18.494   42.63   <2e-16 ***
# TinG          82.214      8.074   10.18   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 193.7 on 254 degrees of freedom
# Multiple R-squared:  0.2899,	Adjusted R-squared:  0.2871
# F-statistic: 103.7 on 1 and 254 DF,  p-value: < 2.2e-16
